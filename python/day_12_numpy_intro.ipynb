# %%
import numpy as np
my_list = [10 , 20 , 30]
arr = np.array(my_list)
print(arr)
print(type(arr))
# Out:
# [10 20 30]
# <class 'numpy.ndarray'>

# %%
list_ = my_list + 5
# it crashes as normal list can't add
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2636825215.py in <cell line: 0>()
# ----> 1 list_ = my_list + 5
#
# TypeError: can only concatenate list (not "int") to list
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2636825215.py in <cell line: 0>()
# ----> 1 list_ = my_list + 5
#
# TypeError: can only concatenate list (not "int") to list

# %%
arr_ = arr + 5
# the numpy array is smart and adds 5 to every element
print(arr_)
# Out:
# [15 25 35]

# %%
marks = np.array([10,15,20,25,28,22,18,19])
print(np.mean(marks))
print(np.max(marks))
print(np.min(marks))
# Out:
# 19.625
# 28
# 10
