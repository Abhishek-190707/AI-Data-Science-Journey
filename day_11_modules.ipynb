# %%
import math
# square root of a number
math.sqrt(25)
# Out:
# 5.0

# %%
# precise area of circle
radius = 5
area = math.pi * (radius ** 2)
print(f"the area of circle of radius {radius} is {area}")
# Out:
# the area of circle of radius 5 is 78.53981633974483

# %%
# lottery system
import random
print("welcome to lottery system")
lottery_no = [1 , 2 , 3 , 4 , 5 , 6 , 7]
winner = random.choice(lottery_no)
print(f"the winner of the lottery is", winner)
# Out:
# welcome to lottery system
# the winner of the lottery is 3

# %%
# user login time
import datetime
current_time = datetime.datetime.now()
print(f"the user logged in at" ,current_time )
# Out:
# the user logged in at 2026-01-22 16:17:28.067286
