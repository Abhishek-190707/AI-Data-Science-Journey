# %%
x = 25
y = 45.45
z = "abhi"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
name = "Abhishek"
print(f"hello" , name)
# Out:
# hello Abhishek

# %%
age1 = int(input("Enter age"))
age2 = int(input("Enter friensd age"))
print(f"sum of age is" , age1 + age2)
# Out:
# Enter age 23
# Enter friensd age 22
# sum of age is 45
